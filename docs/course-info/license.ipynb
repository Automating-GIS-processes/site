# %% [markdown]
# # License and Terms of Use
#
# We are hopeful that the material we provide here is helpful to others. In this
# spirit, we share our teaching material publicly so that it can be used as a
# learning and reference resource, alongside the source code of these pages and
# the notebooks used in the lessons, available [from our GitHub
# repository](https://github.com/Automating-GIS-processes/).
#
# **This material is not open source or open content in the Creative Commons
# sense: it may be read, referenced, and cited, but not copied, redistributed,
# or adapted without permission.** See below for the exact terms.
#
# We are very open to collaboration and to ideas on how to improve this course.
# Please get in touch via [e-mail](./general-information) if you would like to
# propose a change, report an error, or request permission to reuse part of the
# material.
#
# **The material presented here is licensed as explained below**:
#
#
# ## Instructional material
#
# © 2025 Kamyar Hasanzadeh, Department of Geosciences and Geography,
# University of Helsinki. All rights reserved.
#
# This material is made publicly available for **individual learning and
# reference**. You may:
#
# - **read and study** the material for your own personal learning, and
# - **link to and cite** it (with appropriate attribution) as a teaching
#   resource, for example in a syllabus, reading list, or article.
#
# You may **not**, without prior written permission:
#
# - **copy, mirror, or redistribute** the material, in whole or in part, on
#   another website, repository, or platform,
# - **adapt, remix, translate, or build upon** the material to create your own
#   or a derivative course, textbook, or teaching resource, or
# - **use the material commercially**, including as part of a paid course or
#   training.
#
# :::{note}
#
# No warranties are given. Even where use is permitted above, other rights
# such as *publicity, privacy, or moral rights* may still limit how you use the
# material, and use permitted by an applicable exception or limitation (such as
# fair use or fair dealing) is unaffected by these terms.
#
# :::
#
# If you would like to reuse, adapt, or build on this material beyond what is
# described above &mdash; for instance, to teach it at your own institution or
# to publish a derivative version &mdash; please [get in
# touch](./general-information) to request permission.
#
#
# ### Code snippets/Software
#
# Except where otherwise noted, the example programs and code snippets shown in
# the *Automating GIS processes* course are provided for illustration alongside
# the instructional material above, and are covered by the same terms: they may
# be read and studied, but not copied, redistributed, or reused in other
# projects or courses without prior written permission.
